# %% [markdown]
# # Figure 2: Same vs. Other Author Comparisons
#
# From the paper (Figure 2 caption):
# > "Each curve denotes, as a function of the number of training epochs, the t-statistic from a t-test comparing the distribution of losses (across random seeds) assigned to held-out texts from the given author versus held-out texts from all other authors."

# %%
import sys
sys.path.append('..')
from llm_stylometry.visualization import generate_t_test_figure, generate_t_test_avg_figure

# %% [markdown]
# ## Part A: Individual author t-statistics (t_test.pdf)

# %%
fig_2a = generate_t_test_figure(
    data_path='../data/model_results.pkl',
    output_path='../paper/figs/source/t_test.pdf',
    show_legend=False  # No legend for paper version
)

# %% [markdown]
# ## Part B: Average t-statistic (t_test_avg.pdf)

# %%
fig_2b = generate_t_test_avg_figure(
    data_path='../data/model_results.pkl',
    output_path='../paper/figs/source/t_test_avg.pdf',
    show_legend=False  # No legend for paper version
)
