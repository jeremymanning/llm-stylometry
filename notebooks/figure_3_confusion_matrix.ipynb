# %% [markdown]
# # Figure 3: Confusion Matrix
#
# From the paper (Figure 3 caption):
# > "The matrix displays the average cross-entropy loss assigned by models trained on each author's writing (column) to held-out texts from each author (row), after subtracting the native author's baseline loss."

# %%
import sys
sys.path.append('..')
from llm_stylometry.visualization import generate_loss_heatmap_figure

# %% [markdown]
# ## Generate heatmap (average_loss_heatmap.pdf)

# %%
fig_3 = generate_loss_heatmap_figure(
    data_path='../data/model_results.pkl',
    output_path='../paper/figs/source/average_loss_heatmap.pdf'
)
