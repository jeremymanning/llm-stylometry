# %% [markdown]
# # Figure 4: Multidimensional Scaling Plot
#
# From the paper (Figure 4 caption):
# > "Three-dimensional MDS projection of the (symmetrized) average cross-entropy loss matrix shown in Figure 3."

# %%
import sys
sys.path.append('..')
from llm_stylometry.visualization import generate_3d_mds_figure

# %% [markdown]
# ## Generate 3D MDS plot (3d_MDS_plot.pdf)

# %%
fig_4 = generate_3d_mds_figure(
    data_path='../data/model_results.pkl',
    output_path='../paper/figs/source/3d_MDS_plot.pdf'
)
